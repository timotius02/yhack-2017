# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def computeCost(X, y, theta):  
    inner = np.power(((X * theta.T) - y), 2)
    return np.sum(inner) / (2 * len(X))

# %%
path = os.getcwd() + '/data/participant.csv'
p_data = pd.read_csv(path)
p_data.apply(pd.to_numeric, errors='ignore')
p_data = p_data.drop(["collection_id", "email"], axis=1)
p_data.head(10)
# Out:
#       id           city                   DOB  \
# 0    102        Phoenix  1995-04-08T22:11:38Z
# 1   1010  Santa Barbara  1993-03-08T22:11:38Z
# 2   1011  Santa Barbara  1994-07-08T22:11:38Z
# 3   1012         Goleta  1998-10-08T22:11:38Z
# 4   1014       Buellton  1995-10-08T22:11:38Z
# 5   1017         Lompoc  1992-11-08T22:11:38Z
# 6  10125       Quinault  1995-02-08T22:11:38Z
# 7  10127        Taholah  1999-07-08T22:11:38Z
# 8  10128       Westport  1996-06-08T22:11:38Z
# 9  10130     Coupeville  1994-12-08T22:11:38Z
#
#                                address  longitude sex       state  latitude  \
# 0                    910 GRANADA ST #6       -112   M     Arizona        33
# 1               4595 RIDING CLUB COURT       -120   M  California        34
# 2                   1208 HENDERSON AVE       -120   F  California        34
# 3                       3903 WARING RD       -120   M  California        34
# 4                                  NaN       -120   M  California        35
# 5                  2208 COLD STREAM CT       -120   F  California        35
# 6  4891 INDEPENDENCE STREET, SUITE 120       -124   F  Washington        47
# 7               1000 CLAUDIA CT APT #5       -124   F  Washington        47
# 8                    400 N. CONEJO AVE       -124   M  Washington        47
# 9                    3821 RIDGEWAY DR.       -123   M  Washington        48
#
#                              name
# 0              WAHLERT,YIN FONG A
# 1                     VILLA,TIA A
# 2                  BLANDAL,NOEMY
# 3           SPORES,MANDY MIN QIU
# 4       MOORE RISINGER,AUSENCIO M
# 5           KRUKOWSKI,LATOYYA MAE
# 6             MASHORDA,AZELROSE D
# 7          WESTERBECK,ARNYGRACE N
# 8  JORGENSEN-MONTGOMERY,YOUNGER C
# 9                 MOISA,CAILING C

# %%
path = os.getcwd() + '/data/participant_detail.csv'
data = pd.read_csv(path)
data.apply(pd.to_numeric, errors='ignore')
data = data.drop("collection_id", axis=1)
data.head(10)
# Out:
#   EMPLOYMENT_STATUS                                     PRE_CONDITIONS    id  \
# 0        Unemployed  [{"condition_name":"Unspecified fracture of sp...   102
# 1        Unemployed  [{"condition_name":"Unspecified fracture of sp...  1010
# 2        Unemployed  [{"condition_name":"Unspecified fracture of sp...  1011
# 3        Unemployed  [{"condition_name":"Unspecified fracture of sp...  1012
# 4        Unemployed  [{"condition_name":"Unspecified fracture of sp...  1013
# 5        Unemployed  [{"condition_name":"Unspecified fracture of sp...  1014
# 6        Unemployed  [{"condition_name":"Unspecified fracture of sp...  1015
# 7        Unemployed  [{"condition_name":"Unspecified fracture of sp...  1016
# 8        Unemployed  [{"condition_name":"Unspecified fracture of sp...  1017
# 9        Unemployed  [{"condition_name":"Unspecified fracture of sp...  1018
#
#    PEOPLE_COVERED  OPTIONAL_INSURED  ANNUAL_INCOME MARITAL_STATUS  HEIGHT  \
# 0               2            900000         300000              S      63
# 1               1            800000         200000              M      51
# 2               3            700000         100000              S      65
# 3               2            700000         100000              M      62
# 4               4            800000         200000              M      59
# 5               1            600000         300000              S      62
# 6               1            900000         100000              M      54
# 7               3            800000         200000              M      69
# 8               3            600000         300000              S      65
# 9               1            800000         100000              M      63
#
#    WEIGHT TOBACCO
# 0     131      No
# 1     142      No
# 2     164      No
# 3     148      No
# 4     232      No
# 5     145      No
# 6     182      No
# 7     195      No
# 8     292      No
# 9     272      No

# %%
path = os.getcwd() + '/data/quotes.csv'
q_data = pd.read_csv(path)
q_data.apply(pd.to_numeric, errors='ignore')
q_data = q_data.drop("collection_id", axis=1)
q_data.head(10)
# Out:
#    GOLD       id  BRONZE  SILVER  PLATINUM PURCHASED
# 0   216  1017439      76     132       328    Silver
# 1   230  1011372      80     140       350    Silver
# 2   101   101770      36      62       153    Silver
# 3    84    10192      29      51       128    Silver
# 4   243  1019311      93     153       363    Silver
# 5   225  1017853      85     141       337    Silver
# 6   209  1014488      69     125       321    Silver
# 7   230  1019623      80     140       350    Silver
# 8   101   101246      36      62       153    Silver
# 9   240  1018382      90     150       360    Silver

# %%
p_data.describe()
# Out:
#                  id     longitude      latitude
# count  1.111200e+04  11112.000000  11112.000000
# mean   9.226531e+05    -81.311465     40.992261
# std    2.770943e+05     12.710243      3.937288
# min    1.020000e+02   -177.000000     32.000000
# 25%    1.011666e+06    -84.000000     39.000000
# 50%    1.014444e+06    -79.000000     41.000000
# 75%    1.017221e+06    -74.000000     43.000000
# max    1.019999e+06    -68.000000     71.000000

# %%
data.describe()
# Out:
#                  id  PEOPLE_COVERED  OPTIONAL_INSURED   ANNUAL_INCOME  \
# count  1.111200e+04    11112.000000      11112.000000    11112.000000
# mean   9.226531e+05        1.902538     703959.683225   239641.828654
# std    2.770943e+05        1.044309     143708.476353   184779.439163
# min    1.020000e+02        1.000000     500000.000000   100000.000000
# 25%    1.011666e+06        1.000000     600000.000000   100000.000000
# 50%    1.014444e+06        2.000000     700000.000000   200000.000000
# 75%    1.017221e+06        3.000000     800000.000000   300000.000000
# max    1.019999e+06        4.000000    1000000.000000  1000000.000000
#
#              HEIGHT        WEIGHT
# count  11112.000000  11112.000000
# mean      63.910727    166.573974
# std        6.929836     47.969783
# min       50.000000    100.000000
# 25%       61.000000    127.000000
# 50%       64.000000    160.000000
# 75%       68.000000    193.000000
# max       80.000000    299.000000

# %%
q_data.describe()
# Out:
#                GOLD            id       BRONZE        SILVER      PLATINUM
# count  11112.000000  1.111200e+04  11112.00000  11112.000000  11112.000000
# mean     214.670806  9.226531e+05     75.62698    131.244510    325.905868
# std       37.109754  2.770943e+05     14.33472     22.771095     56.992816
# min       72.000000  1.020000e+02     22.00000     42.000000    112.000000
# 25%      216.000000  1.011666e+06     70.00000    130.000000    328.000000
# 50%      225.000000  1.014444e+06     75.00000    135.000000    343.000000
# 75%      230.000000  1.017221e+06     81.00000    140.000000    350.000000
# max      276.000000  1.019999e+06    126.00000    186.000000    396.000000

# %%
result = pd.merge(pd.merge(p_data, data, on="id"), q_data, on="id")
result.head(10)
# Out:
#       id           city                   DOB  \
# 0    102        Phoenix  1995-04-08T22:11:38Z
# 1   1010  Santa Barbara  1993-03-08T22:11:38Z
# 2   1011  Santa Barbara  1994-07-08T22:11:38Z
# 3   1012         Goleta  1998-10-08T22:11:38Z
# 4   1014       Buellton  1995-10-08T22:11:38Z
# 5   1017         Lompoc  1992-11-08T22:11:38Z
# 6  10125       Quinault  1995-02-08T22:11:38Z
# 7  10127        Taholah  1999-07-08T22:11:38Z
# 8  10128       Westport  1996-06-08T22:11:38Z
# 9  10130     Coupeville  1994-12-08T22:11:38Z
#
#                                address  longitude sex       state  latitude  \
# 0                    910 GRANADA ST #6       -112   M     Arizona        33
# 1               4595 RIDING CLUB COURT       -120   M  California        34
# 2                   1208 HENDERSON AVE       -120   F  California        34
# 3                       3903 WARING RD       -120   M  California        34
# 4                                  NaN       -120   M  California        35
# 5                  2208 COLD STREAM CT       -120   F  California        35
# 6  4891 INDEPENDENCE STREET, SUITE 120       -124   F  Washington        47
# 7               1000 CLAUDIA CT APT #5       -124   F  Washington        47
# 8                    400 N. CONEJO AVE       -124   M  Washington        47
# 9                    3821 RIDGEWAY DR.       -123   M  Washington        48
#
#                              name EMPLOYMENT_STATUS    ...     ANNUAL_INCOME  \
# 0              WAHLERT,YIN FONG A        Unemployed    ...            300000
# 1                     VILLA,TIA A        Unemployed    ...            200000
# 2                  BLANDAL,NOEMY         Unemployed    ...            100000
# 3           SPORES,MANDY MIN QIU         Unemployed    ...            100000
# 4       MOORE RISINGER,AUSENCIO M        Unemployed    ...            300000
# 5           KRUKOWSKI,LATOYYA MAE        Unemployed    ...            300000
# 6             MASHORDA,AZELROSE D        Unemployed    ...            300000
# 7          WESTERBECK,ARNYGRACE N        Unemployed    ...            100000
# 8  JORGENSEN-MONTGOMERY,YOUNGER C        Unemployed    ...            700000
# 9                 MOISA,CAILING C        Unemployed    ...            100000
#
#    MARITAL_STATUS  HEIGHT  WEIGHT TOBACCO  GOLD  BRONZE SILVER  PLATINUM  \
# 0               S      63     131      No    99      44     66       143
# 1               M      51     142      No    87      32     54       131
# 2               S      65     164      No    94      39     61       138
# 3               M      62     148      No    82      32     52       122
# 4               S      62     145      No    82      27     49       126
# 5               S      65     292      No    87      32     54       131
# 6               M      77     195      No    87      32     54       131
# 7               M      56     118      No    87      37     57       127
# 8               S      57     161      No    84      29     51       128
# 9               M      62     184      No    99      44     66       143
#
#    PURCHASED
# 0     Bronze
# 1     Silver
# 2     Bronze
# 3     Silver
# 4       Gold
# 5       Gold
# 6       Gold
# 7       Gold
# 8     Silver
# 9       Gold
#
# [10 rows x 23 columns]

# %%
result.plot(kind='scatter', x='ANNUAL_INCOME', y='GOLD', figsize=(12,8))

# %%
result = (result - result.mean()) / result.std()  
result.head()
